# %%
import numpy as np
from axon_approximation import axon_algorithm, AxonModel_np
import matplotlib.pyplot as plt
import pickle

plt.rc('font', size=14)
plt.rcParams.update({"text.usetex": False})

# %%
import nevergrad as ng

# %% [markdown]
# # 1D

# %% [markdown]
# Here we compare perfomance of greedy algorithm with random initalized for several cases:
# * $x^2$
# * $\sqrt{x}$
# * $\exp(-x)$
# * $\sin(20x)$
# * solution of equation: $u(x): -\epsilon^2u''+u = 1,\, u(0)=u(1)=0,\, \epsilon = 0.1, 0.01$
# * $\sqrt{x^2+y^2}$
#
# Results for random initialization are precomputed with *train_random.py* and saved as pickle files

# %%
xs = np.linspace(0,1, 1000)[:,None]

# %%
def plot_errors(data, data_rnd, title):
    plt.plot(np.arange(1,len(data)+1), data, label='axon algorithm')
    plt.plot(np.arange(1,len(data_rnd)+1), data_rnd, label='random initialization')
    plt.yscale('log')
    plt.ylabel('error')
    plt.xlabel('K')
    plt.title(title)
    plt.legend()
    plt.xticks(np.arange(0,102, 10))

# %%
def plot_basis(data, name):
    plt.figure(figsize=(10,6))
    for i in range(6):
        plt.subplot(2,3,i+1)
        plt.ylabel(r'$\phi_{}(x)$'.format(i))
        plt.xlabel(r'$x$')
        if i == 0:
            plt.plot(np.linspace(0,1,1000), np.ones(1000)*data[0,0]) 
            # otherwise the constant function is has strange value
        else:
            plt.plot(np.linspace(0,1,1000), data[:,i])
    plt.tight_layout()

# %% [markdown]
# $x^2$

# %%
model = AxonModel_np()

# %%
ys = (xs**2).flatten()
errs_x2 = model.train(xs, ys, 10, new_obj=False)

# %%
preds = model.forward(xs)
np.linalg.norm(preds-ys)/np.linalg.norm(ys)
# Out:
# np.float64(2.2170329709669166e-05)

# %%
ys = (xs**2).flatten()
# apply algorithm to data, ojective from paper
bs_x2, bs_coefs, r, coefs, norms, errs_x2 = axon_algorithm(xs, ys, 100, new_obj=False)

# %%
errs_rnd = []
with open('error_x2.pkl', 'rb') as f:
    data = pickle.load(f)
    for errs_k in data['error']:
        errors1 = [err for err in errs_k if not np.isnan(err)]
        errs_rnd.append(min(errors1))
plot_errors(errs_x2, errs_rnd, r'$x^2$')

# %%
plot_basis(model.bs, r'$x^2$')

# %%
# to use another objective
bs_x2, bs_coefs, r, coefs, norms, errs_x2_1 = axon_algorithm(xs, ys, 100)

# %%
plt.plot(np.arange(1,len(errs_x2)+1), errs_x2, label='axon algorithm')
plt.plot(np.arange(1,len(errs_x2_1)+1), errs_x2_1, label='modified algorithm')
plt.yscale('log')
plt.ylabel('error')
plt.xlabel('K')
plt.title(r'$x^2$')
plt.legend()
plt.xticks(np.arange(0,len(errs_x2)+2, 10))
plt.show()

# %% [markdown]
# $\sqrt{x}$

# %%
ys = (np.sqrt(xs)).flatten()
bs_sqrt, bs_coefs, r, coefs, norms, errs_sqrt = axon_algorithm(xs, ys, 100, new_obj=False)

# %%
errs_rnd = []
with open('error_sqrt.pkl', 'rb') as f:
    data = pickle.load(f)
    for errs_k in data['error']:
        errors1 = [err for err in errs_k if not np.isnan(err)]
        errs_rnd.append(min(errors1))
plot_errors(errs_sqrt, errs_rnd, r'$\sqrt{x}$')

# %%
plot_basis(bs_sqrt, r'$\sqrt{x}$')

# %%
# to use another objective
bs_sqrt, bs_coefs, r, coefs, norms, errs_sqrt_1 = axon_algorithm(xs, ys, 100)

# %%
plt.plot(np.arange(1,len(errs_sqrt)+1), errs_sqrt, label='axon algorithm')
plt.plot(np.arange(1,len(errs_sqrt_1)+1), errs_sqrt_1, label='modified algorithm')
plt.yscale('log')
plt.ylabel('error')
plt.xlabel('K')
plt.title(r'$x^2$')
plt.legend()
plt.xticks(np.arange(0,len(errs_sqrt)+2, 10))
plt.show()

# %% [markdown]
# $\exp(-x)$

# %%
ys = (np.exp(-xs)).flatten()
bs_exp, bs_coefs, r, coefs, norms, errs_exp = axon_algorithm(xs, ys, 100, new_obj=False)

# %%
errs_rnd = []
with open('error_exp.pkl', 'rb') as f:
    data = pickle.load(f)
    for errs_k in data['error']:
        errors1 = [err for err in errs_k if not np.isnan(err)]
        errs_rnd.append(min(errors1))
plot_errors(errs_exp, errs_rnd, r'$\exp(-x)$')

# %%
plot_basis(bs_exp, r'$\exp(-x)$')

# %% [markdown]
# $\sin(20x)$

# %%
ys = (np.sin(20*xs)).flatten()
bs_sin, bs_coefs, r, coefs, norms, errs_sin = axon_algorithm(xs, ys, 100, new_obj=False)

# %%
errs_rnd = []
with open('error_sin.pkl', 'rb') as f:
    data = pickle.load(f)
    for errs_k in data['error']:
        errors1 = [err for err in errs_k if not np.isnan(err)]
        errs_rnd.append(min(errors1))
plot_errors(errs_sin, errs_rnd, r'$\sin(20x)$')

# %%
plot_basis(bs_sin, r'$\sin(20x)$')

# %% [markdown]
# $u(x): -\epsilon^2u''+u = 1, u(0)=u(1)=0$

# %%
# we found solution analytically
def u(x, eps=0.05):
    a = (1-np.exp(1/eps))/(np.exp(2/eps)-1)
    b = (np.exp(1/eps)-np.exp(2/eps))/(np.exp(2/eps)-1)
    return a*np.exp(x/eps)+b*np.exp(-x/eps) + 1

# %%
eps = 0.01
ys = u(xs, eps)
bs_001, bs_coefs, r, coefs, norms, errs_001 = axon_algorithm(xs, ys, 100, new_obj=False)

# %%
bs_x2, bs_coefs, r, coefs, norms, errs_001_1 = axon_algorithm(xs, ys, 100)

# %%
plt.plot(np.arange(1,len(errs_001)+1), errs_001, label='axon algorithm')
plt.plot(np.arange(1,len(errs_001_1)+1), errs_001_1, label='modified algorithm')
plt.yscale('log')
plt.ylabel('error')
plt.xlabel('K')
plt.title(r"$u(x): -\epsilon^2u''+u = 1, u(0)=u(1)=0, \epsilon={}$".format(eps))
plt.legend()
plt.xticks(np.arange(0,len(errs_001)+2, 10))
plt.show()

# %%
errs_rnd = []
with open('error_diff.pkl', 'rb') as f:
    data = pickle.load(f)
    for errs_k in data['error'][eps]:
        errors1 = [err for err in errs_k if not np.isnan(err)]
        errs_rnd.append(min(errors1))
plot_errors(errs_001, errs_rnd, r"$u(x): -\epsilon^2u''+u = 1, u(0)=u(1)=0, \epsilon={}$".format(eps))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[29], line 2
#       1 errs_rnd = []
# ----> 2 with open('error_diff.pkl', 'rb') as f:
#       3     data = pickle.load(f)
#       4     for errs_k in data['error'][eps]:
#
# File ~/anaconda3/envs/nna/lib/python3.11/site-packages/IPython/core/interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'error_diff.pkl'

# %%
plot_basis(bs_001, r"$u(x): -\epsilon^2u''+u = 1, u(0)=u(1)=0, \epsilon={}$".format(eps))

# %%
eps = 0.1
ys = u(xs, eps)
bs_01, bs_coefs, r, coefs, norms, errs_01 = axon_algorithm(xs, ys, 100, new_obj=False)

# %%
bs_x2, bs_coefs, r, coefs, norms, errs_01_1 = axon_algorithm(xs, ys, 100)

# %%
plt.plot(np.arange(1,len(errs_01)+1), errs_01, label='axon algorithm')
plt.plot(np.arange(1,len(errs_01_1)+1), errs_01_1, label='modified algorithm')
plt.yscale('log')
plt.ylabel('error')
plt.xlabel('K')
plt.title(r"$u(x): -\epsilon^2u''+u = 1, u(0)=u(1)=0, \epsilon={}$".format(eps))
plt.legend()
plt.xticks(np.arange(0,len(errs_01)+2, 10))
plt.show()

# %%
errs_rnd = []
with open('error_diff.pkl', 'rb') as f:
    data = pickle.load(f)
    for errs_k in data['error'][eps]:
        errors1 = [err for err in errs_k if not np.isnan(err)]
        errs_rnd.append(min(errors1))
plot_errors(errs_01, errs_rnd, r"$u(x): -\epsilon^2u''+u = 1, u(0)=u(1)=0, \epsilon={}$".format(eps))

# %%
plot_basis(bs_01, r"$u(x): -\epsilon^2u''+u = 1, u(0)=u(1)=0, \epsilon={}$".format(eps))

# %% [markdown]
# # 2D

# %% [markdown]
# $\sqrt{x^2+y^2}$

# %%
def f(x):
    return np.sqrt(xs[:,0]**2+xs[:,1]**2).astype(np.float64)

# %%
x = np.linspace(-1,1,100)
xx, yy = np.meshgrid(x,x)
xs = np.hstack([xx.flatten()[:,np.newaxis], yy.flatten()[:,np.newaxis]])
ys = f(xs)
bs_2d, bs_coefs, r, coefs, norms, errs_2d = axon_algorithm(xs, ys, 100, new_obj=False)

# %%
errs_rnd = []
with open('error_2d.pkl', 'rb') as f:
    data = pickle.load(f)
    for errs_k in data['error']:
        errors1 = [err for err in errs_k if not np.isnan(err)]
        errs_rnd.append(min(errors1))
plot_errors(errs_2d, errs_rnd, r'$\sqrt(x^2+y^2)$')

# %%
plt.figure(figsize=(12,9))
for i in range(9):
    plt.subplot(3,3,i+1)
    #plt.title(r'$\phi_{}$'.format(i+5))
    plt.ylabel(r'$y$'.format(i))
    plt.xlabel(r'$x$')
    plt.contourf(xx, yy, bs_2d[:,i].reshape(100,100, order='C'))
    plt.colorbar()
plt.tight_layout()
